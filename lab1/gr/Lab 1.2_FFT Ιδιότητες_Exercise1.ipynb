# %% [markdown]
# # Άσκηση 1
# ## Ιδιότητες μετασχηματισμού FFT σε πραγματικές εικόνες

# %% [markdown]
# Εφαρμόστε τις ιδιότητες του μετασχηματισμού FFT στις δύο εικόνες (house.tif και woman_blonde.tif) που θα βρείτε <a href="https://drive.google.com/file/d/1lbWM5YTl0nVqH5XA-f-Eow1qUI2MLQWo">εδώ</a> και χρησιμοποιώντας την εξίσωση (3), απεικονίστε τα εξής:
#
# > α) τις αρχικές εικόνες
#
# > β) τη γωνία φάσης και το φάσμα των εικόνων αυτών
#
# > γ) την ανακατασκευή των αρχικών εικόνων με τη χρήση αντίστροφου FFT, με  τη χρήση αντίστροφου FFT μόνο του πραγματικού μέρος τους και με  τη χρήση αντίστροφου FFT μόνο του φανταστικού μέρος της
#
# > δ) την ανακατασκευή των αρχικών εικόνων χρησιμοποιώντας μόνο το φάσμα
#
# > ε) την ανακατασκευή των αρχικών εικόνων χρησιμοποιώντας τη γωνία φάση
#
# >στ) την ανακατασκευή νέας εικόνας χρησιμοποιώντας το φάσμα της μίας και τη φάση της άλλης από τις αρχικές εικόνες

# %% [markdown]
# Import functions and libraries

# %% [markdown]
# Εμφάνιση αρχικών εικόνων και έλεγχος διάστασης τους(Να έχουν την ίδια διάσταση)

# %% [markdown]
# Εφαρμογή fft2 σε ολόκληρη την εικόνα (και για τις 2 εικόνες)

# %% [markdown]
# ... συνέχεια ...
